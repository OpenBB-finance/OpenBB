# %%
# Import most generic modules
import os
import sys
from datetime import datetime
from IPython.display import display, Markdown
import warnings

warnings.filterwarnings('ignore')
module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
report_name = f"{datetime.now().strftime('%Y%m%d_%H%M%S')}_crypto_market"

# %%
display(Markdown(f"# Crypto Market - {datetime.now().strftime('%Y/%m/%d %H:%M:%S')}"))
# Out:
# # Crypto Market - 2022/01/18 12:15:59

# %% [markdown]
# ## Bitcoin Chart

# %%
from gamestonk_terminal.cryptocurrency import cryptocurrency_helpers
coin_map_df = cryptocurrency_helpers.prepare_all_coins_df().set_index('Symbol').loc['btc']
cryptocurrency_helpers.plot_chart(
    coin='btc-bitcoin', source='cp', currency='USD', days=60, coin_map_df=coin_map_df
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Global Market Information

# %%
from gamestonk_terminal.cryptocurrency.overview import coinpaprika_view

coinpaprika_view.display_global_market(export='')
# Out:
# Parser must be a string or character stream, not datetime
# ╒══════════════════════════════╤═════════════════════╕
# │ Metric                       │ Value               │
# ╞══════════════════════════════╪═════════════════════╡
# │ market_cap_usd               │ 2.060 T             │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_usd               │ 135.844 B           │
# ├──────────────────────────────┼─────────────────────┤
# │ bitcoin_dominance_percentage │ 38.240              │
# ├──────────────────────────────┼─────────────────────┤
# │ cryptocurrencies_number      │ 6.694 K             │
# ├──────────────────────────────┼─────────────────────┤
# │ market_cap_ath_value         │ 3.629 T             │
# ├──────────────────────────────┼─────────────────────┤
# │ market_cap_ath_date          │ 2021-10-27 07:40:00 │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_ath_value         │ 1.388 T             │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_ath_date          │ 2021-05-02 17:00:00 │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_percent_from_ath  │ -90.210             │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_percent_to_ath    │ 921.900             │
# ├──────────────────────────────┼─────────────────────┤
# │ market_cap_change_24h        │ -2.030              │
# ├──────────────────────────────┼─────────────────────┤
# │ volume_24h_change_24h        │ 18.270              │
# ├──────────────────────────────┼─────────────────────┤
# │ last_updated                 │ 2022-01-18 12:14:54 │
# ╘══════════════════════════════╧═════════════════════╛

# %% [markdown]
# ## Top coins market information

# %%
from gamestonk_terminal.cryptocurrency.overview import coinpaprika_view

coinpaprika_view.display_all_coins_market_info(
    currency='USD', sortby='volume_24h', descend=True, top=10, export=''
)
# Out:
# Displaying data vs USD
# ╒════════╤═══════════════════════╤══════════╤══════════╤══════════════╤═══════════════════╤═════════════════╤══════════════════╤═════════════╤════════════════╕
# │   rank │ name                  │ symbol   │ price    │   volume_24h │   mcap_change_24h │   pct_change_1h │   pct_change_24h │ ath_price   │   pct_from_ath │
# ╞════════╪═══════════════════════╪══════════╪══════════╪══════════════╪═══════════════════╪═════════════════╪══════════════════╪═════════════╪════════════════╡
# │      1 │ Bitcoin               │ BTC      │ 41.611 K │            0 │                 0 │           0.060 │           -1.430 │ 68.692 K    │        -39.420 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4467 │ Crypto Rewards Studio │ CRS      │ 0.004    │            0 │                 0 │           4.450 │            0.480 │ 0.007       │        -42.030 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4466 │ Timecoin Protocol     │ TMCN     │ 0.390    │            0 │                 0 │           0.120 │            1.320 │ 24.321 K    │       -100.000 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4465 │ Derivex               │ DVX      │ 0.001    │            0 │                 0 │          -0.050 │           -4.020 │ 0.001       │        -37.360 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4464 │ CVS Health            │ CVS      │ 104.180  │            0 │                 0 │          -0.040 │           -0.260 │ 105.945     │         -1.670 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4464 │ MDsquare              │ TMED     │ 0.000    │            0 │                 0 │           0.000 │            4.890 │ 0.000       │        -75.660 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4462 │ WHEN Token            │ WHEN     │ 0.001    │            0 │                 0 │           0.120 │          -43.780 │ 0.061       │        -99.150 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4462 │ NFTBlackmarket        │ NBM      │ 0.000    │            0 │                 0 │           0.800 │            1.160 │ 0.000       │        -61.560 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4460 │ Let's Go Farming      │ LGF      │ 0.000    │            0 │                 0 │           0.030 │           -6.340 │ 0.000       │        -78.780 │
# ├────────┼───────────────────────┼──────────┼──────────┼──────────────┼───────────────────┼─────────────────┼──────────────────┼─────────────┼────────────────┤
# │   4459 │ Kanaloa Network       │ KANA     │ 0.001    │            0 │                 0 │           0.600 │           -2.090 │ 378.657     │       -100.000 │
# ╘════════╧═══════════════════════╧══════════╧══════════╧══════════════╧═══════════════════╧═════════════════╧══════════════════╧═════════════╧════════════════╛

# %% [markdown]
# ## Top gainers in last 24h

# %%
from gamestonk_terminal.cryptocurrency.discovery import pycoingecko_view

pycoingecko_view.display_gainers(
    period='24h', top=10, export=''
)

# %% [markdown]
# ## Top losers in last 24h

# %%
from gamestonk_terminal.cryptocurrency.discovery import pycoingecko_view

pycoingecko_view.display_losers(
    period='24h', top=10, export=''
)

# %% [markdown]
# ## Coins trending on coingecko

# %%
from gamestonk_terminal.cryptocurrency.discovery import pycoingecko_view

pycoingecko_view.display_trending(
    export='',
)

# %% [markdown]
# ## Decentralized Finance Global Market Info

# %%
from gamestonk_terminal.cryptocurrency.overview import pycoingecko_view

pycoingecko_view.display_global_defi_info(export='')

# %% [markdown]
# ## Top DeFi Coins

# %%
from gamestonk_terminal.cryptocurrency.discovery import pycoingecko_view

pycoingecko_view.display_top_defi_coins(
    top=10, export=''
)

# %% [markdown]
# ## Top Decentralized Exchanges

# %%
from gamestonk_terminal.cryptocurrency.discovery import dappradar_view

dappradar_view.display_top_dexes(top=10, export='')

# %%
# !jupyter nbconvert {report_name + '.ipynb'} --to html --no-input
