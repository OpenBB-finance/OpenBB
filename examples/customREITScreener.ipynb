# %% [markdown]
# ## customREITScreener
#
# #### Description
# This notebook demonstrates how to screen and filter Real Estate Investment Trusts (REITs) based on financial metrics such as market capitalization, price-to-book ratio, beta, overall risk, and dividend yield using OpenBB's fundamental data. It allows users to set specific criteria to identify REITs that match their investment preferences.
#
# #### Author
# [Ambrose Ikpele](https://github.com/ambroseikpele)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OpenBB-Finance/OpenBB/blob/develop/examples/customREITScreener.ipynb)

# %%
# !pip install openbb
# Out:
# Collecting openbb
#   Downloading openbb-4.3.4-py3-none-any.whl.metadata (12 kB)
# Collecting openbb-benzinga<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_benzinga-1.3.4-py3-none-any.whl.metadata (979 bytes)
# Collecting openbb-bls<2.0.0,>=1.0.2 (from openbb)
#   Downloading openbb_bls-1.0.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting openbb-cftc<2.0.0,>=1.0.2 (from openbb)
#   Downloading openbb_cftc-1.0.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting openbb-commodity<2.0.0,>=1.2.5 (from openbb)
#   Downloading openbb_commodity-1.2.5-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-core<2.0.0,>=1.3.5 (from openbb)
#   Downloading openbb_core-1.3.5-py3-none-any.whl.metadata (3.5 kB)
# Collecting openbb-crypto<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_crypto-1.3.4-py3-none-any.whl.metadata (993 bytes)
# Collecting openbb-currency<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_currency-1.3.4-py3-none-any.whl.metadata (994 bytes)
# Collecting openbb-derivatives<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_derivatives-1.3.4-py3-none-any.whl.metadata (958 bytes)
# Collecting openbb-econdb<2.0.0,>=1.2.4 (from openbb)
#   Downloading openbb_econdb-1.2.4-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-economy<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_economy-1.3.4-py3-none-any.whl.metadata (999 bytes)
# Collecting openbb-equity<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_equity-1.3.4-py3-none-any.whl.metadata (1.5 kB)
# Collecting openbb-etf<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_etf-1.3.4-py3-none-any.whl.metadata (828 bytes)
# Collecting openbb-federal-reserve<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_federal_reserve-1.3.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-fixedincome<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_fixedincome-1.3.4-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-fmp<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_fmp-1.3.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-fred<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_fred-1.3.4-py3-none-any.whl.metadata (976 bytes)
# Collecting openbb-imf<2.0.0,>=1.0.1 (from openbb)
#   Downloading openbb_imf-1.0.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting openbb-index<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_index-1.3.4-py3-none-any.whl.metadata (994 bytes)
# Collecting openbb-intrinio<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_intrinio-1.3.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-news<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_news-1.3.4-py3-none-any.whl.metadata (952 bytes)
# Collecting openbb-oecd<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_oecd-1.3.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-platform-api<2.0.0,>=1.0.3 (from openbb)
#   Downloading openbb_platform_api-1.0.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting openbb-polygon<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_polygon-1.3.4-py3-none-any.whl.metadata (968 bytes)
# Collecting openbb-regulators<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_regulators-1.3.4-py3-none-any.whl.metadata (983 bytes)
# Collecting openbb-sec<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_sec-1.3.4-py3-none-any.whl.metadata (1.1 kB)
# Collecting openbb-tiingo<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_tiingo-1.3.4-py3-none-any.whl.metadata (967 bytes)
# Collecting openbb-tradingeconomics<2.0.0,>=1.3.4 (from openbb)
#   Downloading openbb_tradingeconomics-1.3.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting openbb-yfinance<2.0.0,>=1.3.5 (from openbb)
#   Downloading openbb_yfinance-1.3.5-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (3.10.10)
# Collecting fastapi<0.116,>=0.115 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (8.5.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (2.2.2)
# Collecting posthog<4.0.0,>=3.3.1 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (2.9.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (2.9.0)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting python-multipart<0.0.8,>=0.0.7 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading python_multipart-0.0.7-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.1 in /usr/local/lib/python3.10/dist-packages (from openbb-core<2.0.0,>=1.3.5->openbb) (2.32.3)
# Collecting ruff<0.8,>=0.7 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading ruff-0.7.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting uuid7<0.2.0,>=0.1.0 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading uuid7-0.1.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting uvicorn<0.33.0,>=0.32.0 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<14.0,>=13.0 (from openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting aiohttp-client-cache<0.12.0,>=0.11.0 (from openbb-econdb<2.0.0,>=1.2.4->openbb)
#   Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting aiosqlite<0.21.0,>=0.20.0 (from openbb-econdb<2.0.0,>=1.2.4->openbb)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting requests-cache<2.0.0,>=1.1.0 (from openbb-intrinio<2.0.0,>=1.3.4->openbb)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting defusedxml<0.9.0,>=0.8.0rc2 (from openbb-oecd<2.0.0,>=1.3.4->openbb)
#   Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.10/dist-packages (from openbb-oecd<2.0.0,>=1.3.4->openbb) (2.2.3)
# Collecting black (from openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 4.3 MB/s eta 0:00:00
# Collecting deepdiff (from openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting poetry<2.0,>=1.8 (from openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading poetry-1.8.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from openbb-platform-api<2.0.0,>=1.0.3->openbb) (75.1.0)
# Collecting bs4<0.0.3,>=0.0.2 (from openbb-sec<2.0.0,>=1.3.4->openbb)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting lxml<6.0.0,>=5.2.1 (from openbb-sec<2.0.0,>=1.3.4->openbb)
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting xmltodict<0.14.0,>=0.13.0 (from openbb-sec<2.0.0,>=1.3.4->openbb)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: yfinance<0.3.0,>=0.2.46 in /usr/local/lib/python3.10/dist-packages (from openbb-yfinance<2.0.0,>=1.3.5->openbb) (0.2.48)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (4.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.2.4->openbb) (2.2.0)
# Collecting url-normalize<2.0,>=1.4 (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.2.4->openbb)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiosqlite<0.21.0,>=0.20.0->openbb-econdb<2.0.0,>=1.2.4->openbb) (4.12.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4<0.0.3,>=0.0.2->openbb-sec<2.0.0,>=1.3.4->openbb) (4.12.3)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.3.5->openbb) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.3.5->openbb) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.3.5->openbb) (3.20.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.3.5->openbb) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.3.5->openbb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.3.5->openbb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.3.5->openbb) (2024.2)
# Collecting build<2.0.0,>=1.0.3 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: cachecontrol<0.15.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (0.14.0)
# Collecting cleo<3.0.0,>=2.1.0 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading cleo-2.1.0-py3-none-any.whl.metadata (12 kB)
# Collecting crashtest<0.5.0,>=0.4.1 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading crashtest-0.4.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting dulwich<0.22.0,>=0.21.2 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (2.20.0)
# Collecting installer<0.8.0,>=0.7.0 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading installer-0.7.0-py3-none-any.whl.metadata (936 bytes)
# Collecting keyring<25.0.0,>=24.0.0 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading keyring-24.3.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (24.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (4.9.0)
# Collecting pkginfo<2.0,>=1.10 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading pkginfo-1.11.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs<5,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (4.3.6)
# Collecting poetry-core==1.9.1 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading poetry_core-1.9.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting poetry-plugin-export<2.0.0,>=1.6.0 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading poetry_plugin_export-1.8.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyproject-hooks<2.0.0,>=1.0.0 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (1.0.0)
# Requirement already satisfied: shellingham<2.0,>=1.5 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (1.5.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (2.0.2)
# Collecting tomlkit<1.0.0,>=0.11.4 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting trove-classifiers>=2022.5.19 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading trove_classifiers-2024.10.21.16-py3-none-any.whl.metadata (2.2 kB)
# Collecting virtualenv<21.0.0,>=20.26.6 (from poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading virtualenv-20.27.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting monotonic>=1.5 (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.3.5->openbb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.3.5->openbb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.3.5->openbb) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.3.5->openbb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.3.5->openbb) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.3.5->openbb) (2024.8.30)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.3.4->openbb)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn<0.33.0,>=0.32.0->openbb-core<2.0.0,>=1.3.5->openbb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn<0.33.0,>=0.32.0->openbb-core<2.0.0,>=1.3.5->openbb) (0.14.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3.0,>=0.2.46->openbb-yfinance<2.0.0,>=1.3.5->openbb) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3.0,>=0.2.46->openbb-yfinance<2.0.0,>=1.3.5->openbb) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3.0,>=0.2.46->openbb-yfinance<2.0.0,>=1.3.5->openbb) (3.17.7)
# Collecting mypy-extensions>=0.4.3 (from black->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting orderly-set==5.2.2 (from deepdiff->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4<0.0.3,>=0.0.2->openbb-sec<2.0.0,>=1.3.4->openbb) (2.6)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol<0.15.0,>=0.14.0->cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (1.1.0)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.15.0,>=0.14.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (3.16.1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.3.4->openbb) (1.2.2)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from cleo<3.0.0,>=2.1.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting jaraco.classes (from keyring<25.0.0,>=24.0.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.3.5->openbb) (3.7.1)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.26.6->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.10.4->openbb-core<2.0.0,>=1.3.5->openbb) (0.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.3.5->openbb) (1.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry<2.0,>=1.8->openbb-platform-api<2.0.0,>=1.0.3->openbb) (10.5.0)
# Downloading openbb-4.3.4-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 18.1 MB/s eta 0:00:00
# Downloading openbb_benzinga-1.3.4-py3-none-any.whl (14 kB)
# Downloading openbb_bls-1.0.2-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 77.1 MB/s eta 0:00:00
# Downloading openbb_cftc-1.0.2-py3-none-any.whl (12 kB)
# Downloading openbb_commodity-1.2.5-py3-none-any.whl (3.0 kB)
# Downloading openbb_core-1.3.5-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.3/280.3 kB 12.5 MB/s eta 0:00:00
# Downloading openbb_crypto-1.3.4-py3-none-any.whl (4.0 kB)
# Downloading openbb_currency-1.3.4-py3-none-any.whl (4.9 kB)
# Downloading openbb_derivatives-1.3.4-py3-none-any.whl (7.0 kB)
# Downloading openbb_econdb-1.2.4-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.3/96.3 kB 4.8 MB/s eta 0:00:00
# Downloading openbb_economy-1.3.4-py3-none-any.whl (13 kB)
# Downloading openbb_equity-1.3.4-py3-none-any.whl (15 kB)
# Downloading openbb_etf-1.3.4-py3-none-any.whl (5.1 kB)
# Downloading openbb_federal_reserve-1.3.4-py3-none-any.whl (25 kB)
# Downloading openbb_fixedincome-1.3.4-py3-none-any.whl (13 kB)
# Downloading openbb_fmp-1.3.4-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.7 MB/s eta 0:00:00
# Downloading openbb_fred-1.3.4-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.0/106.0 kB 5.6 MB/s eta 0:00:00
# Downloading openbb_imf-1.0.1-py3-none-any.whl (23 kB)
# Downloading openbb_index-1.3.4-py3-none-any.whl (4.2 kB)
# Downloading openbb_intrinio-1.3.4-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 7.8 MB/s eta 0:00:00
# Downloading openbb_news-1.3.4-py3-none-any.whl (2.8 kB)
# Downloading openbb_oecd-1.3.4-py3-none-any.whl (36 kB)
# Downloading openbb_platform_api-1.0.3-py3-none-any.whl (14 kB)
# Downloading openbb_polygon-1.3.4-py3-none-any.whl (33 kB)
# Downloading openbb_regulators-1.3.4-py3-none-any.whl (4.8 kB)
# Downloading openbb_sec-1.3.4-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.9 MB/s eta 0:00:00
# Downloading openbb_tiingo-1.3.4-py3-none-any.whl (13 kB)
# Downloading openbb_tradingeconomics-1.3.4-py3-none-any.whl (8.3 kB)
# Downloading openbb_yfinance-1.3.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.1 MB/s eta 0:00:00
# Downloading aiohttp_client_cache-0.11.1-py3-none-any.whl (32 kB)
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading defusedxml-0.8.0rc2-py2.py3-none-any.whl (25 kB)
# Downloading fastapi-0.115.4-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 8.4 MB/s eta 0:00:00
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 61.4 MB/s eta 0:00:00
# Downloading poetry-1.8.4-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 19.9 MB/s eta 0:00:00
# Downloading poetry_core-1.9.1-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 23.7 MB/s eta 0:00:00
# Downloading posthog-3.7.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading python_multipart-0.0.7-py3-none-any.whl (22 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 5.4 MB/s eta 0:00:00
# Downloading ruff-0.7.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 69.3 MB/s eta 0:00:00
# Downloading uuid7-0.1.0-py2.py3-none-any.whl (7.5 kB)
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.2 MB/s eta 0:00:00
# Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 16.1 MB/s eta 0:00:00
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 51.6 MB/s eta 0:00:00
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.6 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.0 MB/s eta 0:00:00
# Downloading cleo-2.1.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.3 MB/s eta 0:00:00
# Downloading crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 30.4 MB/s eta 0:00:00
# Downloading installer-0.7.0-py3-none-any.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 21.3 MB/s eta 0:00:00
# Downloading keyring-24.3.1-py3-none-any.whl (38 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pkginfo-1.11.2-py3-none-any.whl (31 kB)
# Downloading poetry_plugin_export-1.8.0-py3-none-any.whl (10 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading starlette-0.41.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 6.8 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading trove_classifiers-2024.10.21.16-py3-none-any.whl (13 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading virtualenv-20.27.1-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 56.3 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 21.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.3 MB/s eta 0:00:00
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Installing collected packages: trove-classifiers, monotonic, distlib, xmltodict, websockets, virtualenv, uvicorn, uuid7, url-normalize, tomlkit, ruff, rapidfuzz, python-multipart, python-dotenv, pyproject-hooks, poetry-core, pkginfo, pathspec, orderly-set, mypy-extensions, lxml, jaraco.classes, installer, dulwich, defusedxml, crashtest, cattrs, backoff, aiosqlite, starlette, requests-cache, posthog, keyring, deepdiff, cleo, build, bs4, black, fastapi, openbb-core, aiohttp-client-cache, openbb-yfinance, openbb-tradingeconomics, openbb-tiingo, openbb-sec, openbb-regulators, openbb-polygon, openbb-oecd, openbb-news, openbb-intrinio, openbb-index, openbb-imf, openbb-fred, openbb-fmp, openbb-fixedincome, openbb-federal-reserve, openbb-etf, openbb-equity, openbb-economy, openbb-econdb, openbb-derivatives, openbb-currency, openbb-crypto, openbb-commodity, openbb-cftc, openbb-bls, openbb-benzinga, poetry-plugin-export, poetry, openbb-platform-api, openbb
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.4
#     Uninstalling lxml-4.9.4:
#       Successfully uninstalled lxml-4.9.4
#   Attempting uninstall: defusedxml
#     Found existing installation: defusedxml 0.7.1
#     Uninstalling defusedxml-0.7.1:
#       Successfully uninstalled defusedxml-0.7.1
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
# Successfully installed aiohttp-client-cache-0.11.1 aiosqlite-0.20.0 backoff-2.2.1 black-24.10.0 bs4-0.0.2 build-1.2.2.post1 cattrs-24.1.2 cleo-2.1.0 crashtest-0.4.1 deepdiff-8.0.1 defusedxml-0.8.0rc2 distlib-0.3.9 dulwich-0.21.7 fastapi-0.115.4 installer-0.7.0 jaraco.classes-3.4.0 keyring-24.3.1 lxml-5.3.0 monotonic-1.6 mypy-extensions-1.0.0 openbb-4.3.4 openbb-benzinga-1.3.4 openbb-bls-1.0.2 openbb-cftc-1.0.2 openbb-commodity-1.2.5 openbb-core-1.3.5 openbb-crypto-1.3.4 openbb-currency-1.3.4 openbb-derivatives-1.3.4 openbb-econdb-1.2.4 openbb-economy-1.3.4 openbb-equity-1.3.4 openbb-etf-1.3.4 openbb-federal-reserve-1.3.4 openbb-fixedincome-1.3.4 openbb-fmp-1.3.4 openbb-fred-1.3.4 openbb-imf-1.0.1 openbb-index-1.3.4 openbb-intrinio-1.3.4 openbb-news-1.3.4 openbb-oecd-1.3.4 openbb-platform-api-1.0.3 openbb-polygon-1.3.4 openbb-regulators-1.3.4 openbb-sec-1.3.4 openbb-tiingo-1.3.4 openbb-tradingeconomics-1.3.4 openbb-yfinance-1.3.5 orderly-set-5.2.2 pathspec-0.12.1 pkginfo-1.11.2 poetry-1.8.4 poetry-core-1.9.1 poetry-plugin-export-1.8.0 posthog-3.7.0 pyproject-hooks-1.2.0 python-dotenv-1.0.1 python-multipart-0.0.7 rapidfuzz-3.10.1 requests-cache-1.2.1 ruff-0.7.1 starlette-0.41.2 tomlkit-0.13.2 trove-classifiers-2024.10.21.16 url-normalize-1.4.3 uuid7-0.1.0 uvicorn-0.32.0 virtualenv-20.27.1 websockets-13.1 xmltodict-0.13.0

# %%
import pandas as pd
from openbb import obb
from typing import Optional

# %% [markdown]
# ### Creating The List of REITs
# The list of REITS on the [stock analysis](https://stockanalysis.com/list/reit-stocks/) website was collected and used to generate the below REITs dictionary in the below cell

# %%
# The reits_dct with the relevant REITs' tickers
reits_dct={
            'PLD': 'Prologis, Inc.',
            'AMT': 'American Tower Corporation',
            'EQIX': 'Equinix, Inc.',
            'WELL': 'Welltower Inc.',
            'DLR': 'Digital Realty Trust, Inc.',
            'PSA': 'Public Storage',
            'SPG': 'Simon Property Group, Inc.',
            'O': 'Realty Income Corporation',
            'CCI': 'Crown Castle Inc.',
            'IRM': 'Iron Mountain Incorporated',
            'EXR': 'Extra Space Storage Inc.',
            'VICI': 'VICI Properties Inc.',
            'AVB': 'AvalonBay Communities, Inc.',
            'EQR': 'Equity Residential',
            'VTR': 'Ventas, Inc.',
            'SBAC': 'SBA Communications Corporation',
            'WY': 'Weyerhaeuser Company',
            'INVH': 'Invitation Homes Inc.',
            'ARE': 'Alexandria Real Estate Equities, Inc.',
            'ESS': 'Essex Property Trust, Inc.',
            'MAA': 'Mid-America Apartment Communities, Inc.',
            'LINE': 'Lineage, Inc.',
            'SUI': 'Sun Communities, Inc.',
            'KIM': 'Kimco Realty Corporation',
            'DOC': 'Healthpeak Properties, Inc.',
            'UDR': 'UDR, Inc.',
            'AMH': 'American Homes 4 Rent',
            'GLPI': 'Gaming and Leisure Properties, Inc.',
            'BXP': 'BXP, Inc.',
            'LAMR': 'Lamar Advertising Company',
            'REG': 'Regency Centers Corporation',
            'ELS': 'Equity LifeStyle Properties, Inc.',
            'CPT': 'Camden Property Trust',
            'WPC': 'W. P. Carey Inc.',
            'HST': 'Host Hotels & Resorts, Inc.',
            'CUBE': 'CubeSmart',
            'OHI': 'Omega Healthcare Investors, Inc.',
            'NLY': 'Annaly Capital Management, Inc.',
            'REXR': 'Rexford Industrial Realty, Inc.',
            'FRT': 'Federal Realty Investment Trust',
            'EGP': 'EastGroup Properties, Inc.',
            'NNN': 'NNN REIT, Inc.',
            'BRX': 'Brixmor Property Group Inc.',
            'VNO': 'Vornado Realty Trust',
            'AGNC': 'AGNC Investment Corp.',
            'ADC': 'Agree Realty Corporation',
            'COLD': 'Americold Realty Trust, Inc.',
            'FR': 'First Industrial Realty Trust, Inc.',
            'STAG': 'STAG Industrial, Inc.',
            'STWD': 'Starwood Property Trust, Inc.',
            'RHP': 'Ryman Hospitality Properties, Inc.',
            'HR': 'Healthcare Realty Trust Incorporated',
            'TRNO': 'Terreno Realty Corporation',
            'EPRT': 'Essential Properties Realty Trust, Inc.',
            'KRG': 'Kite Realty Group Trust',
            'RITM': 'Rithm Capital Corp.',
            'SLG': 'SL Green Realty Corp.',
            'KRC': 'Kilroy Realty Corporation',
            'CTRE': 'CareTrust REIT, Inc.',
            'CUZ': 'Cousins Properties Incorporated',
            'RYN': 'Rayonier Inc.',
            'PECO': 'Phillips Edison & Company, Inc.',
            'SBRA': 'Sabra Health Care REIT, Inc.',
            'IRT': 'Independence Realty Trust, Inc.',
            'MAC': 'The Macerich Company',
            'AHR': 'American Healthcare REIT, Inc.',
            'IIPR': 'Innovative Industrial Properties, Inc.',
            'SKT': 'Tanger Inc.',
            'HIW': 'Highwoods Properties, Inc.',
            'CDP': 'COPT Defense Properties',
            'APLE': 'Apple Hospitality REIT, Inc.',
            'EPR': 'EPR Properties',
            'NHI': 'National Health Investors, Inc.',
            'BNL': 'Broadstone Net Lease, Inc.',
            'PCH': 'PotlatchDeltic Corporation',
            'NSA': 'National Storage Affiliates Trust',
            'BXMT': 'Blackstone Mortgage Trust, Inc.',
            'OUT': 'OUTFRONT Media Inc.',
            'DEI': 'Douglas Emmett, Inc.',
            'PK': 'Park Hotels & Resorts Inc.',
            'ESBA': 'Empire State Realty OP, L.P.',
            'ABR': 'Arbor Realty Trust, Inc.',
            'MPW': 'Medical Properties Trust, Inc.',
            'LXP': 'LXP Industrial Trust',
            'UE': 'Urban Edge Properties',
            'FCPT': 'Four Corners Property Trust, Inc.',
            'AKR': 'Acadia Realty Trust',
            'IVT': 'InvenTrust Properties Corp.',
            'EQC': 'Equity Commonwealth',
            'SHO': 'Sunstone Hotel Investors, Inc.',
            'ROIC': 'Retail Opportunity Investments Corp.',
            'DRH': 'DiamondRock Hospitality Company',
            'GNL': 'Global Net Lease, Inc.',
            'ESRT': 'Empire State Realty Trust, Inc.',
            'GTY': 'Getty Realty Corp.',
            'SAFE': 'Safehold Inc.',
            'AAT': 'American Assets Trust, Inc.',
            'VRE': 'Veris Residential, Inc.',
            'JBGS': 'JBG SMITH Properties',
            'LTC': 'LTC Properties, Inc.',
            'ELME': 'Elme Communities',
            'PEB': 'Pebblebrook Hotel Trust',
            'XHR': 'Xenia Hotels & Resorts, Inc.',
            'UMH': 'UMH Properties, Inc.',
            'LADR': 'Ladder Capital Corp',
            'DEA': 'Easterly Government Properties, Inc.',
            'RLJ': 'RLJ Lodging Trust',
            'SILA': 'Sila Realty Trust, Inc.',
            'ALEX': 'Alexander & Baldwin, Inc.',
            'UNIT': 'Uniti Group Inc.',
            'TWO': 'Two Harbors Investment Corp.',
            'MFA': 'MFA Financial, Inc.',
            'PDM': 'Piedmont Office Realty Trust, Inc.',
            'CIM': 'Chimera Investment Corporation',
            'AIV': 'Apartment Investment and Management Company',
            'ARI': 'Apollo Commercial Real Estate Finance, Inc.',
            'NTST': 'NETSTREIT Corp.',
            'PMT': 'PennyMac Mortgage Investment Trust',
            'ALX': "Alexander's, Inc.",
            'RC': 'Ready Capital Corporation',
            'NXRT': 'NexPoint Residential Trust, Inc.',
            'PGRE': 'Paramount Group, Inc.',
            'EFC': 'Ellington Financial Inc.',
            'CSR': 'Centerspace',
            'FBRT': 'Franklin BSP Realty Trust, Inc.',
            'ARR': 'ARMOUR Residential REIT, Inc.',
            'RWT': 'Redwood Trust, Inc.',
            'DX': 'Dynex Capital, Inc.',
            'BFS': 'Saul Centers, Inc.',
            'PLYM': 'Plymouth Industrial REIT, Inc.',
            'BDN': 'Brandywine Realty Trust',
            'SITC': 'SITE Centers Corp.',
            'CMTG': 'Claros Mortgage Trust, Inc.',
            'AHH': 'Armada Hoffler Properties, Inc.',
            'DHC': 'Diversified Healthcare Trust',
            'CBL': 'CBL & Associates Properties, Inc.',
            'KREF': 'KKR Real Estate Finance Trust Inc.',
            'WSR': 'Whitestone REIT',
            'BRSP': 'BrightSpire Capital, Inc.',
            'GOOD': 'Gladstone Commercial Corporation',
            'INN': 'Summit Hotel Properties, Inc.',
            'TRTX': 'TPG RE Finance Trust, Inc.',
            'ORC': 'Orchid Island Capital, Inc.',
            'HPP': 'Hudson Pacific Properties, Inc.',
            'GMRE': 'Global Medical REIT Inc.',
            'CTO': 'CTO Realty Growth, Inc.',
            'OLP': 'One Liberty Properties, Inc.',
            'SVC': 'Service Properties Trust',
            'UHT': 'Universal Health Realty Income Trust',
            'FPI': 'Farmland Partners Inc.',
            'PKST': 'Peakstone Realty Trust',
            'NYMT': 'New York Mortgage Trust, Inc.',
            'LAND': 'Gladstone Land Corporation',
            'CHCT': 'Community Healthcare Trust Incorporated',
            'IVR': 'Invesco Mortgage Capital Inc.',
            'NLOP': 'Net Lease Office Properties',
            'CLDT': 'Chatham Lodging Trust',
            'ACRE': 'Ares Commercial Real Estate Corporation',
            'PSTL': 'Postal Realty Trust, Inc.',
            'BRT': 'BRT Apartments Corp.',
            'REFI': 'Chicago Atlantic Real Estate Finance, Inc.',
            'FVR': 'FrontView REIT, Inc.',
            'ILPT': 'Industrial Logistics Properties Trust',
            'PINE': 'Alpine Income Property Trust, Inc.',
            'NREF': 'NexPoint Real Estate Finance, Inc.',
            'CIO': 'City Office REIT, Inc.',
            'ONL': 'Orion Office REIT Inc.',
            'AOMR': 'Angel Oak Mortgage REIT, Inc.',
            'MITT': 'AG Mortgage Investment Trust, Inc.',
            'AFCG': 'Advanced Flower Capital Inc.',
            'SEVN': 'Seven Hills Realty Trust',
            'BHR': 'Braemar Hotels & Resorts Inc.',
            'FSP': 'Franklin Street Properties Corp.',
            'MDV': 'Modiv Industrial, Inc.',
            'GPMT': 'Granite Point Mortgage Trust Inc.',
            'AJX': 'Great Ajax Corp.',
            'LFT': 'Lument Finance Trust, Inc.',
            'SACH': 'Sachem Capital Corp.',
            'ACR': 'ACRES Commercial Realty Corp.',
            'CLPR': 'Clipper Realty Inc.',
            'CHMI': 'Cherry Hill Mortgage Investment Corporation',
            'OPI': 'Office Properties Income Trust',
            'SUNS': 'Sunrise Realty Trust, Inc.',
            'STRW': 'Strawberry Fields REIT, Inc.',
            'LOAN': 'Manhattan Bridge Capital, Inc.',
            'BHM': 'Bluerock Homes Trust, Inc.',
            'SELF': 'Global Self Storage, Inc.',
            'SOHO': 'Sotherly Hotels Inc.',
            'IHT': 'InnSuites Hospitality Trust',
            'MDRR': 'Medalist Diversified REIT, Inc.',
            'CMCT': 'Creative Media & Community Trust Corporation',
            'GIPR': 'Generation Income Properties, Inc.',
            'WHLR': 'Wheeler Real Estate Investment Trust, Inc.',
            'SQFT': 'Presidio Property Trust, Inc.',
            'PW': 'Power REIT',
            'AHT': 'Ashford Hospitality Trust, Inc.'
}

# %% [markdown]
# ### Creating The Screener Function
# In creating the `screener` function, we made use of yahoo finance data and filtered based on the properties provided by the data. If you intend to change the data provider make sure to filter based on the properties provided by their data.

# %%
def screener(
    mktcap_min: Optional[int] = None,
    mktcap_max: Optional[int] = None,
    price_to_book_min: Optional[float] = None,
    price_to_book_max: Optional[float] = None,
    beta_min: Optional[float] = None,
    beta_max: Optional[float] = None,
    overall_risk_min: Optional[int] = None,
    overall_risk_max: Optional[int] = None,
    dividend_yield_min: Optional[float] = None,
    dividend_yield_max: Optional[float] = None,
    limit: Optional[int] = None
) -> pd.DataFrame:
    """
    Screens Real Estate Investment Trusts (REITs) based on specified financial metrics.

    Parameters:
    ----------
        Data provider for fetching REITs metrics. Supports providers like 'yfinance'.
    mktcap_min : Optional[int], default None
        Minimum market capitalization for filtering.
    mktcap_max : Optional[int], default None
        Maximum market capitalization for filtering.
    price_to_book_min : Optional[float], default None
        Minimum price-to-book ratio for filtering.
    price_to_book_max : Optional[float], default None
        Maximum price-to-book ratio for filtering.
    beta_min : Optional[float], default None
        Minimum beta value for filtering, indicating volatility.
    beta_max : Optional[float], default None
        Maximum beta value for filtering, indicating volatility.
    overall_risk_min : Optional[int], default None
        Minimum overall risk score for filtering.
    overall_risk_max : Optional[int], default None
        Maximum overall risk score for filtering.
    dividend_yield_min : Optional[float], default None
        Minimum dividend yield percentage for filtering.
    dividend_yield_max : Optional[float], default None
        Maximum dividend yield percentage for filtering.
    limit : Optional[int], default None
        Limits the number of records in the output DataFrame.

    Returns:
    -------
    DataFrame:
        A DataFrame of REITs that meet the specified criteria.

    Notes:
    ------
    This function fetches REITs metrics using the yahoo finance data provider,
    then filters the data based on the user specified value for the financial metrics,
    and returns a subset of REITs that match the specified parameters.
    (the number of filtering criteria used here is limited for the sake of example and can be increased to account for other metrics)
    """
    # Fetch metrics

    reits = obb.equity.fundamental.metrics(list(reits_dct.keys()), provider='yfinance').to_df()

    # Apply filters
    if mktcap_min is not None:
        reits = reits[reits['market_cap'] >= mktcap_min]
    if mktcap_max is not None:
        reits = reits[reits['market_cap'] <= mktcap_max]
    if price_to_book_min is not None:
        reits = reits[reits['price_to_book'] >= price_to_book_min]
    if price_to_book_max is not None:
        reits = reits[reits['price_to_book'] <= price_to_book_max]
    if beta_min is not None:
        reits = reits[reits['beta'] >= beta_min]
    if beta_max is not None:
        reits = reits[reits['beta'] <= beta_max]
    if overall_risk_min is not None:
        reits = reits[reits['overall_risk'] >= overall_risk_min]
    if overall_risk_max is not None:
        reits = reits[reits['overall_risk'] <= overall_risk_max]
    if dividend_yield_min is not None:
        reits = reits[reits['dividend_yield'] >= dividend_yield_min]
    if dividend_yield_max is not None:
        reits = reits[reits['dividend_yield'] <= dividend_yield_max]

    # Limit the number of results if specified
    if limit is not None:
        reits = reits.head(limit)

    return reits

# %% [markdown]
# ### Example

# %% [markdown]
# This example demonstrates how to use the `screener` function to filter REITs based on the specified financial criteria:
#
#   - **Market Cap**: Filters REITs with a market capitalization between 50 billion (`mktcap_min=5e10`) and 110 billion (`mktcap_max=1.1e11`).
#   - **Price-to-Book Ratio**: Selects REITs with a price-to-book ratio between 1.0 and 3.0.
#   - **Beta**: Filters REITs with beta values from 0.5 to 1.5, indicating moderate volatility.
#   - **Overall Risk**: Includes REITs with an overall risk rating between 1 and 8.
#   - **Limit**: Limits the results to the top 5 REITs that match these criteria.

# %%
# Example usage of the screener function
filtered_reits = screener(
    provider='yfinance',
    mktcap_min=5e10,            # Minimum market cap of 50 billion
    mktcap_max=1.1e11,          # Maximum market cap of 110 billion
    price_to_book_min=1.0,      # Minimum price-to-book ratio of 1.0
    price_to_book_max=3.0,      # Maximum price-to-book ratio of 3.0
    beta_min=0.5,               # Minimum beta of 0.5
    beta_max=1.5,               # Maximum beta of 1.5
    overall_risk_min=1,         # Minimum overall risk rating
    overall_risk_max=8,         # Maximum overall risk rating
    limit=5                     # Limit to top 5 results
)

# Print the filtered results
filtered_reits
# Out:
#   symbol    market_cap    pe_ratio  forward_pe  peg_ratio  peg_ratio_ttm  \
# 0    PLD  1.073159e+11   34.795800   32.917614      -5.14         0.5263
# 4    DLR  6.134793e+10  155.700850  146.911290     -13.79        13.0779
# 7      O  5.267010e+10   55.999996   38.037735       2.17         6.0761
#
#    enterprise_to_ebitda  earnings_growth  earnings_growth_quarterly  \
# 0                25.109            0.343                      0.345
# 4                34.003           -0.961                     -0.930
# 7                18.694              NaN                      0.327
#
#    revenue_per_share  ...  price_to_book  enterprise_value  overall_risk  \
# 0              8.901  ...       2.024461      1.441056e+11           8.0
# 4             16.985  ...       2.942402      7.917851e+10           8.0
# 7              6.010  ...       1.365114      7.863404e+10           2.0
#
#    audit_risk  board_risk  compensation_risk  shareholder_rights_risk   beta  \
# 0         3.0         6.0                9.0                      8.0  1.081
# 4         5.0         3.0                9.0                      9.0  0.622
# 7         3.0         1.0                4.0                      7.0  0.993
#
#    price_return_1y  currency
# 0         0.106474       USD
# 4         0.398725       USD
# 7         0.208875       USD
#
# [3 rows x 35 columns]
