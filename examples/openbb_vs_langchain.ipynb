# %% [markdown]
# ### Brief Description
#
# This notebook builds a simple agent leveraging OpenBB functionality via  LangChain.
# It requires the user to have
# - an OpenAI Key. This is required as OpenAI is used as LLM
# - an OpenBB PAT - This is used to leverage few OpenBB endpoints
# - You should be a FMP subscriber.This is required as few of openbb calls rely
#   on fmp endpoints.
#
# As consequences of the above, you should configure the following secrets in
# this notebook using the "key" icon on the left
# - PAT_KEY: your OpenBB Pat Key.
# - OPENAI_KEI : your OpenAI key
#
# For help on how to configure Colab Secrets, please refer to this article
# https://margaretmz.medium.com/use-colab-secrets-to-store-kaggle-api-key-b57c7464f9fa
#
# This work was inspired by examples from this repo https://github.com/AlgoTrading101/Magentic-AlgoTrading101
#
# Functionality shown in this notebook is purely an example of what can be done.
#
# ### Author
# Marco Mistroni

# %% [markdown]
# ### Installing dependencies

# %%
# !pip install openbb
# !pip install openbb-finviz
# !pip install openbb-fmp
# !pip install langchain
# !pip install langchain_core
# !pip install langchain_openai
# Out:
# Requirement already satisfied: openbb in /usr/local/lib/python3.11/dist-packages (4.4.4)
# Requirement already satisfied: openbb-benzinga<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-bls<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.1.2)
# Requirement already satisfied: openbb-cftc<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.1.1)
# Requirement already satisfied: openbb-commodity<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.3.1)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.6 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.7)
# Requirement already satisfied: openbb-crypto<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-currency<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-derivatives<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-econdb<2.0.0,>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.3.1)
# Requirement already satisfied: openbb-economy<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.2)
# Requirement already satisfied: openbb-equity<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-etf<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-federal-reserve<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.3)
# Requirement already satisfied: openbb-fixedincome<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.3)
# Requirement already satisfied: openbb-fmp<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.2)
# Requirement already satisfied: openbb-fred<2.0.0,>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.4)
# Requirement already satisfied: openbb-imf<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.1.1)
# Requirement already satisfied: openbb-index<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-intrinio<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-news<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-oecd<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-platform-api<2.0.0,>=1.1.6 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.1.10)
# Requirement already satisfied: openbb-polygon<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-regulators<2.0.0,>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.2)
# Requirement already satisfied: openbb-sec<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.3)
# Requirement already satisfied: openbb-tiingo<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-tradingeconomics<2.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.1)
# Requirement already satisfied: openbb-us-eia<2.0.0,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.1.1)
# Requirement already satisfied: openbb-yfinance<2.0.0,>=1.4.3 in /usr/local/lib/python3.11/dist-packages (from openbb) (1.4.6)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (3.11.15)
# Requirement already satisfied: fastapi<0.116,>=0.115 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (0.115.12)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (8.7.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (2.2.2)
# Requirement already satisfied: posthog<4.0.0,>=3.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (3.25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (2.11.4)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (1.1.0)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (2.32.3)
# Requirement already satisfied: ruff<0.8,>=0.7 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (0.7.4)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (0.1.0)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (0.34.2)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb) (15.0.1)
# Requirement already satisfied: aiohttp-client-cache<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from openbb-econdb<2.0.0,>=1.3.1->openbb) (0.11.1)
# Requirement already satisfied: aiosqlite<0.21.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from openbb-econdb<2.0.0,>=1.3.1->openbb) (0.20.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.13.4 in /usr/local/lib/python3.11/dist-packages (from openbb-federal-reserve<2.0.0,>=1.4.2->openbb) (4.13.4)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-intrinio<2.0.0,>=1.4.1->openbb) (1.2.1)
# Requirement already satisfied: defusedxml<0.9.0,>=0.8.0rc2 in /usr/local/lib/python3.11/dist-packages (from openbb-oecd<2.0.0,>=1.4.1->openbb) (0.8.0rc2)
# Requirement already satisfied: urllib3>1.26.16 in /usr/local/lib/python3.11/dist-packages (from openbb-oecd<2.0.0,>=1.4.1->openbb) (2.4.0)
# Requirement already satisfied: deepdiff in /usr/local/lib/python3.11/dist-packages (from openbb-platform-api<2.0.0,>=1.1.6->openbb) (8.5.0)
# Requirement already satisfied: inscriptis<3.0.0,>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.3->openbb) (2.6.0)
# Requirement already satisfied: lxml<6.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.3->openbb) (5.4.0)
# Requirement already satisfied: trafilatura<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.3->openbb) (2.0.0)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from openbb-sec<2.0.0,>=1.4.3->openbb) (0.13.0)
# Requirement already satisfied: async-lru<3.0.0,>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.1->openbb) (2.0.5)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.1->openbb) (3.1.5)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from openbb-us-eia<2.0.0,>=1.1.1->openbb) (2.0.1)
# Requirement already satisfied: curl-adapter<2.0.0,>=1.0.0.post3 in /usr/local/lib/python3.11/dist-packages (from openbb-yfinance<2.0.0,>=1.4.3->openbb) (1.0.0.post3)
# Requirement already satisfied: yfinance==0.2.58 in /usr/local/lib/python3.11/dist-packages (from openbb-yfinance<2.0.0,>=1.4.3->openbb) (0.2.58)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (3.18.1)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (0.10.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb) (1.20.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.1->openbb) (2.2.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from aiohttp-client-cache<0.12.0,>=0.11.0->openbb-econdb<2.0.0,>=1.3.1->openbb) (1.4.3)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.11/dist-packages (from aiosqlite<0.21.0,>=0.20.0->openbb-econdb<2.0.0,>=1.3.1->openbb) (4.13.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.13.4->openbb-federal-reserve<2.0.0,>=1.4.2->openbb) (2.7)
# Requirement already satisfied: pycurl==7.45.3 in /usr/local/lib/python3.11/dist-packages (from curl-adapter<2.0.0,>=1.0.0.post3->openbb-yfinance<2.0.0,>=1.4.3->openbb) (7.45.3)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb) (0.46.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.6->openbb) (3.21.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl<4.0.0,>=3.1.5->openbb-us-eia<2.0.0,>=1.1.1->openbb) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb) (2025.2)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb) (2025.4.26)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache<2.0.0,>=1.1.0->openbb-intrinio<2.0.0,>=1.4.1->openbb) (24.1.3)
# Requirement already satisfied: courlan>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (1.3.2)
# Requirement already satisfied: htmldate>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (1.9.3)
# Requirement already satisfied: justext>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (3.0.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb) (8.2.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb) (0.16.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from deepdiff->openbb-platform-api<2.0.0,>=1.1.6->openbb) (5.4.1)
# Requirement already satisfied: babel>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (2.17.0)
# Requirement already satisfied: tld>=0.13 in /usr/local/lib/python3.11/dist-packages (from courlan>=1.3.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (0.13)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (1.17.1)
# Requirement already satisfied: dateparser>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (1.2.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance==0.2.58->openbb-yfinance<2.0.0,>=1.4.3->openbb) (2.22)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.11/dist-packages (from dateparser>=1.1.2->htmldate>=1.9.2->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (5.3.1)
# Requirement already satisfied: lxml_html_clean in /usr/local/lib/python3.11/dist-packages (from lxml[html_clean]>=4.4.2->justext>=3.0.1->trafilatura<3.0,>=2.0->openbb-sec<2.0.0,>=1.4.3->openbb) (0.4.2)
# Requirement already satisfied: openbb-finviz in /usr/local/lib/python3.11/dist-packages (1.3.1)
# Requirement already satisfied: finvizfinance<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-finviz) (1.1.0)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.6 in /usr/local/lib/python3.11/dist-packages (from openbb-finviz) (1.4.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (4.13.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (5.4.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (3.11.15)
# Requirement already satisfied: fastapi<0.116,>=0.115 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.115.12)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (8.7.0)
# Requirement already satisfied: posthog<4.0.0,>=3.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (3.25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (2.11.4)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.1.0)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.0.20)
# Requirement already satisfied: ruff<0.8,>=0.7 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.7.4)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.1.0)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.34.2)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-finviz) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.20.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (4.13.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2025.2)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2025.4.26)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (8.2.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->finvizfinance<2.0.0,>=1.1.0->openbb-finviz) (2.7)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-finviz) (1.3.1)
# Requirement already satisfied: openbb-fmp in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: openbb-core<2.0.0,>=1.4.6 in /usr/local/lib/python3.11/dist-packages (from openbb-fmp) (1.4.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (3.11.15)
# Requirement already satisfied: fastapi<0.116,>=0.115 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.115.12)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (8.7.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.2.2)
# Requirement already satisfied: posthog<4.0.0,>=3.3.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (3.25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.11.4)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.10.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.1.0)
# Requirement already satisfied: python-multipart<0.0.21,>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.0.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.1 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.32.3)
# Requirement already satisfied: ruff<0.8,>=0.7 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.7.4)
# Requirement already satisfied: uuid7<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.1.0)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.34.2)
# Requirement already satisfied: websockets<16.0,>=15.0 in /usr/local/lib/python3.11/dist-packages (from openbb-core<2.0.0,>=1.4.6->openbb-fmp) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.11->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.20.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.46.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (4.13.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib<2.0,>=1.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (3.21.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.5.3->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2025.2)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from posthog<4.0.0,>=3.3.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.1->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (2025.4.26)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (8.2.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (0.16.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<0.116,>=0.115->openbb-core<2.0.0,>=1.4.6->openbb-fmp) (1.3.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.25)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.59)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain_core in /usr/local/lib/python3.11/dist-packages (0.3.59)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain_core) (2.11.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_core) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_core) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_core) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain_core) (0.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.3.1)
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.17-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in /usr/local/lib/python3.11/dist-packages (from langchain_openai) (0.3.59)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from langchain_openai) (1.78.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.11/dist-packages (from langchain_openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.59->langchain_openai) (2.11.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.68.2->langchain_openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain_openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_openai) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain_openai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.59->langchain_openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.4.0)
# Downloading langchain_openai-0.3.17-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: langchain_openai
# Successfully installed langchain_openai-0.3.17

# %% [markdown]
# ### Getting keys

# %%
from google.colab import userdata
PAT_KEY = userdata.get('PAT_KEY')
OPENAI_KEY = userdata.get('OPENAI_KEY')

# %%
from openbb import obb
import os
from langchain_openai import ChatOpenAI
import logging
from langchain.agents import tool
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0, openai_api_key=OPENAI_KEY)

# %% [markdown]
# ### OpenBB Useful functions

# %%
@tool
def get_industry_performance() -> list:
    """ Return performance by industry for last week, last month, last quarter, last half year and last year"""
    return obb.equity.compare.groups(group='industry', metric='performance').to_llm()

@tool
def get_strong_buy_for_sector(sector : str) -> list :
    """ Return the strong buy recommendation for a given sector"""
    new_sector = '_'.join(sector.lower().split()).lower()
    data = obb.equity.screener(provider='finviz', sector=new_sector, recommendation='buy')
    return data.to_llm()

@tool
def get_strong_buy_for_industry(industry : str) -> list :
    """ Return the strong buy recommendation for a given industry"""
    data = obb.equity.screener(provider='finviz', industry=industry, recommendation='buy')
    return data.to_llm()

@tool
def get_best_stock_performers_for_sector(sector:str) -> list :
    """ Return the best  5 stock performers for last week and last month for a given sector"""
    data = obb.equity.screener(provider='finviz', filters_dict={'Sector' : sector, 'Performance' : 'Week Up', 'Performance 2' : 'Month Up'}, limit=5)
    return data.to_llm()

@tool
def get_best_stock_performers_for_industry(industry:str) -> list :
    """ Return the best  5 stock performers for last week and last month for an industry"""
    data = obb.equity.screener(provider='finviz', filters_dict={'Industry' : industry, 'Performance' : 'Week Up', 'Performance 2' : 'Month Up'}, limit=3)
    return data.to_llm()

@tool
def get_candidate_stocks_to_invest_relaxed(industry:str) -> list:
    ''' Use relaxed criterias to find best companies in an industry  which are worth investing into'''
    desc_filters = {
            'Market Cap.': '+Small (over $300mln)',
            'Average Volume': 'Over 200K',
        }
    fund_filters = {
        'InstitutionalOwnership': 'Under 60%',
        'Current Ratio' :  'Over 1.5',
        'Debt/Equity'   : 'Over 0.3',
        #'EPS growthnext 5 years' : 'Positive (>0%)',
    }

    desc_filters.update(fund_filters)

    try:
        data = obb.equity.screener(provider='finviz', industry='semiconductors',
                    filters_dict=desc_filters
                    )
        return data.to_llm()
    except Exception as e:
        logging.info(f'No data found:{str(e)}')
        return []


@tool
def get_valuation_for_industries(input:str) -> list:
    """ Return valuation meetrics for the industry provided as input"""
    data =  obb.equity.compare.groups(group='industry', metric='valuation', provider='finviz').to_df()
    filtered =  data[data.name == input]
    return filtered.to_json(
            orient="records",
            date_format="iso",
            date_unit="s",
        )

@tool
def get_valuation_for_company(ticker:str) -> list:
    """ Return Valuation metrics for a company"""
    # requires obb login
    obb.account.login(pat=PAT_KEY)
    return obb.equity.fundamental.ratios(symbol=ticker, provider='fmp', limit=1).to_llm()

@tool
def get_income_statement(ticker:str) -> list:
    """ Return the last 3  annual income statement for  a given ticker
        metrics returned are
        - revenue
        - gross profit
        - cost of revenue
        - consolidated net income, which represents net income


    """
    obb.account.login(pat=PAT_KEY)
    fields_to_extract = ['revenue', 'gross_profit', 'cost_of_revenue', 'consolidated_net_income' ]
    data = obb.equity.fundamental.income(symbol=ticker, limit=3, provider='fmp').to_df()[::-1]
    filtered = data[fields_to_extract]
    return filtered.to_json(
            orient="records",
            date_format="iso",
            date_unit="s",
        )

@tool
def get_company_metrics(ticker:str) -> list:
    """ Fetch metrics for a company. It will return the following metrics:
        - pe_ratio
        - foward_pe
        - eps
        - price_to_sales
        - price_to_book
        - book_value_per_share
        - price_to_cash
        - cash_per_share
        - price_to_free_cash_flow
        - debt_to_equity
        - long_term_debt_to_equity
        - quick_ratio
        - current_ratio
        - gross_margin
        - profit_margin
        - operating_margin
        - return_on_assets
        - return_on_investment
        - return_on_equity
        - payout_ratio
    """
    obb.account.login(pat=PAT_KEY)
    data = obb.equity.fundamental.metrics(symbol=ticker).to_df()
    return data.to_json(
            orient="records",
            date_format="iso",
            date_unit="s",
        )

# %% [markdown]
# ### Chat Memory

# %%
from langchain_core.prompts import MessagesPlaceholder
from langchain.memory import ConversationTokenBufferMemory
#from langchain_core.messages import count_tokens_approximately
from langchain.agents.format_scratchpad.openai_tools import (
    format_to_openai_tool_messages,
)
from langchain.agents.output_parsers.openai_tools import OpenAIToolsAgentOutputParser
from langchain_core.output_parsers import StrOutputParser, CommaSeparatedListOutputParser
from langchain.agents import AgentExecutor
from langchain_core.messages import AIMessage, HumanMessage

MEMORY_KEY = "chat_history"
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """ You are very powerful stock financial researcher.
                You  will take the user questions and answer using the tools available.
                Once you have the information you  need, you will answer user's questions using the data returned.
                Use the following tools to answer user queries:
                - get_strong_buy_for_sector to find strong buy recommendations for a sector
                - get_strong_buy_for_industry to find strong buy recommendations for an industry
                - get_industry_performance to find the performance for an industry
                - get_valuation_for_industries to find valuation metrics for industries
                - get_candidate_stocks_to_invest_relaxed to  fetch all companies using relaxed criteria
                - get_income_statement to find income statements for a company
                - get_company_metrics to find financial metrics for a company
                - get_valuation_for_company to find valuation metrics for a company
                You should call each function only once, and you should not call the function if you already have the information you need.
                """,
        ),
        MessagesPlaceholder(variable_name=MEMORY_KEY),
        ("user", "{input}"),
        MessagesPlaceholder(variable_name="agent_scratchpad"),
    ]
)

# %%
tools = [get_industry_performance, get_strong_buy_for_sector, get_strong_buy_for_industry, get_best_stock_performers_for_industry, get_valuation_for_industries,
         get_candidate_stocks_to_invest_relaxed, get_income_statement, get_company_metrics]
llm_with_tools = llm.bind_tools(tools)

# %%
chat_history = []
chat_history.append(HumanMessage(content="Your question here"))
chat_history.append(AIMessage(content="AI response here"))
memory = ConversationTokenBufferMemory(
    llm=llm,  # Required for token counting
    max_token_limit=16000,  # Leave buffer for functions + responses
    memory_key="chat_history",  # Must match your prompt's key
    return_messages=True
)

agent = (
    {
        "input": lambda x: x["input"],
        "agent_scratchpad": lambda x: format_to_openai_tool_messages(
            x["intermediate_steps"]
        ),
        "chat_history": lambda x: memory.load_memory_variables(x)["chat_history"],
    }
    | prompt
    | llm_with_tools
    | OpenAIToolsAgentOutputParser()
)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)
# Out:
# <ipython-input-7-12cf89d03b47>:4: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationTokenBufferMemory(

# %% [markdown]
# ### Let's try a chain of thought approach. We start with the industry with best performance.
# Then find the best performing company  and check some metrics

# %%
input1 = '''
First, find a industry that has consistently shown positive performance across quarterly, monthly, and weekly timeframes.
Second, once you have identified the industry, extract its relevant valuation metrics (e.g., P/E, P/B, EV/EBITDA).
Third, extract companies from the selected industry using relaxed criteria.
Fourth, from the income statement for  the top performer compute revenue growth in percentage across the years in the data/
Finally, summarize your findings in no more than 80 words detailing:
- Best performing industry
- Best performing company in industry
- A table displaying for each year the revenue growth percentage'''
result = agent_executor.invoke({"input": input1, "chat_history": chat_history})
print(result['output'])
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `get_industry_performance` with `{}`
#
#
# [{"name":"REIT - Hotel & Motel","performance_1d":-0.0183,"performance_1w":-0.04,"performance_1m":0.1068,"performance_3m":-0.15,"performance_6m":-0.172,"performance_1y":-0.2079,"performance_ytd":-0.1746,"analyst_recommendation":1.95,"volume":27960000,"volume_average":35690000,"volume_relative":0.78},{"name":"Solar","performance_1d":0.012,"performance_1w":-0.0395,"performance_1m":0.3226,"performance_3m":-0.0288,"performance_6m":-0.1116,"performance_1y":-0.696,"performance_ytd":-0.0532,"analyst_recommendation":1.92,"volume":58280000,"volume_average":83730000,"volume_relative":0.7},{"name":"Oil & Gas E&P","performance_1d":-0.0051,"performance_1w":-0.0362,"performance_1m":0.0729,"performance_3m":-0.1001,"performance_6m":-0.1223,"performance_1y":-0.165,"performance_ytd":-0.0553,"analyst_recommendation":1.78,"volume":149610000,"volume_average":207170000,"volume_relative":0.72},{"name":"Residential Construction","performance_1d":-0.0151,"performance_1w":-0.0358,"performance_1m":0.0519,"performance_3m":-0.056,"performance_6m":-0.2515,"performance_1y":-0.1797,"performance_ytd":-0.1166,"analyst_recommendation":2.32,"volume":14310000,"volume_average":19750000,"volume_relative":0.72},{"name":"Oil & Gas Equipment & Services","performance_1d":-0.0133,"performance_1w":-0.0327,"performance_1m":0.0303,"performance_3m":-0.1854,"performance_6m":-0.1777,"performance_1y":-0.2092,"performance_ytd":-0.1311,"analyst_recommendation":1.69,"volume":62550000,"volume_average":95630000,"volume_relative":0.65},{"name":"Resorts & Casinos","performance_1d":-0.0218,"performance_1w":-0.0309,"performance_1m":0.1962,"performance_3m":-0.0989,"performance_6m":-0.1258,"performance_1y":-0.1161,"performance_ytd":-0.1126,"analyst_recommendation":1.83,"volume":23150000,"volume_average":38050000,"volume_relative":0.61},{"name":"Chemicals","performance_1d":-0.0042,"performance_1w":-0.0307,"performance_1m":0.0991,"performance_3m":-0.2084,"performance_6m":-0.3321,"performance_1y":-0.524,"performance_ytd":-0.2661,"analyst_recommendation":2.5,"volume":29750000,"volume_average":30420000,"volume_relative":0.98},{"name":"Oil & Gas Drilling","performance_1d":-0.0092,"performance_1w":-0.0305,"performance_1m":0.1521,"performance_3m":-0.2198,"performance_6m":-0.334,"performance_1y":-0.4572,"performance_ytd":-0.2781,"analyst_recommendation":1.76,"volume":49890000,"volume_average":68900000,"volume_relative":0.72},{"name":"Internet Retail","performance_1d":-0.006,"performance_1w":-0.029,"performance_1m":0.2127,"performance_3m":-0.0678,"performance_6m":0.0303,"performance_1y":0.1456,"performance_ytd":0.0161,"analyst_recommendation":1.31,"volume":115470000,"volume_average":180710000,"volume_relative":0.64},{"name":"Oil & Gas Integrated","performance_1d":-0.0069,"performance_1w":-0.028,"performance_1m":0.022,"performance_3m":-0.0717,"performance_6m":-0.0816,"performance_1y":-0.1324,"performance_ytd":-0.0052,"analyst_recommendation":1.92,"volume":82430000,"volume_average":116740000,"volume_relative":0.71},{"name":"Real Estate - Diversified","performance_1d":-0.0136,"performance_1w":-0.0275,"performance_1m":0.0851,"performance_3m":-0.0507,"performance_6m":-0.1264,"performance_1y":-0.0798,"performance_ytd":-0.0554,"analyst_recommendation":1.43,"volume":667180,"volume_average":779210,"volume_relative":0.86},{"name":"Lumber & Wood Production","performance_1d":-0.012,"performance_1w":-0.0266,"performance_1m":0.0358,"performance_3m":-0.1063,"performance_6m":-0.2151,"performance_1y":-0.1391,"performance_ytd":-0.1156,"analyst_recommendation":1.82,"volume":1690000,"volume_average":1420000,"volume_relative":1.19},{"name":"Consumer Electronics","performance_1d":-0.0074,"performance_1w":-0.025,"performance_1m":0.0718,"performance_3m":-0.1475,"performance_6m":-0.0783,"performance_1y":0.1036,"performance_ytd":-0.161,"analyst_recommendation":2.04,"volume":55890000,"volume_average":77890000,"volume_relative":0.72},{"name":"Thermal Coal","performance_1d":-0.0069,"performance_1w":-0.0237,"performance_1m":0.0 ...
# Invoking: `get_valuation_for_industries` with `{'input': 'Biotechnology'}`
#
#
# [{"name":"Biotechnology","market_cap":785770000000,"performance_1d":0.0182,"pe":44.59,"forward_pe":31.0,"peg":2.43,"eps_growth_past_5y":-0.0895,"eps_growth_next_5y":0.1832,"volume":1340000000,"price_to_sales":8.1,"price_to_book":3.44,"price_to_cash":4.41,"price_to_free_cash_flow":55.07,"sales_growth_past_5_years":4.9842}]
# Invoking: `get_candidate_stocks_to_invest_relaxed` with `{'industry': 'Biotechnology'}`
#
#
# [{"symbol":"HIMX","name":"Himax Technologies ADR","country":"Taiwan","sector":"Technology","industry":"Semiconductors","market_cap":1480000000.0,"price":8.44,"change_percent":0.012,"volume":779086,"price_to_earnings":16.86}]
# Invoking: `get_income_statement` with `{'ticker': 'HIMX'}`
#
#
# [{"revenue":1201339000.0,"gross_profit":487106000.0,"cost_of_revenue":714233000.0,"consolidated_net_income":236982000.0},{"revenue":945428000.0,"gross_profit":263497000.0,"cost_of_revenue":681931000.0,"consolidated_net_income":50616000.0},{"revenue":906802000.0,"gross_profit":276201000.0,"cost_of_revenue":630601000.0,"consolidated_net_income":79755000.0}]The best performing industry is Biotechnology, with consistent positive performance across quarterly, monthly, and weekly timeframes. The industry has a market capitalization of $785.77 billion and a price-to-earnings ratio of 44.59. One of the top companies in the Biotechnology industry is Himax Technologies ADR, a Taiwanese company in the Technology sector. The company's revenue growth percentage across the years is as follows:
#
# - Revenue Growth Percentage:
#   - Year 1: 27.1%
#   - Year 2: -10.0%
#   - Year 3: 27.3%
#
# In summary:
# - Best Performing Industry: Biotechnology
# - Best Performing Company in Industry: Himax Technologies ADR
# - Revenue Growth Percentage Table:
#   | Year | Revenue Growth Percentage |
#   |------|---------------------------|
#   | 1    | 27.1%                     |
#   | 2    | -10.0%                    |
#   | 3    | 27.3%                     |
#
# > Finished chain.
# The best performing industry is Biotechnology, with consistent positive performance across quarterly, monthly, and weekly timeframes. The industry has a market capitalization of $785.77 billion and a price-to-earnings ratio of 44.59. One of the top companies in the Biotechnology industry is Himax Technologies ADR, a Taiwanese company in the Technology sector. The company's revenue growth percentage across the years is as follows:
#
# - Revenue Growth Percentage:
#   - Year 1: 27.1%
#   - Year 2: -10.0%
#   - Year 3: 27.3%
#
# In summary:
# - Best Performing Industry: Biotechnology
# - Best Performing Company in Industry: Himax Technologies ADR
# - Revenue Growth Percentage Table:
#   | Year | Revenue Growth Percentage |
#   |------|---------------------------|
#   | 1    | 27.1%                     |
#   | 2    | -10.0%                    |
#   | 3    | 27.3%                     |

# %% [markdown]
# ### Finding strong buys in the Utilities sector
